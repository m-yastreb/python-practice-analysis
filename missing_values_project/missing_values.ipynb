# %% [markdown]
# ## Задание 1
# ### Этап 1. Получение данных
#
# Сначала изучим данные, предоставленные для проекта.
#
# Набор данных содержит подробную информацию об общем количестве проходов пассажиров на станции метрополитена через турникеты по входу и об общем количестве выходов, осуществленных пассажирами со станций метрополитена.
# Источник данных: Портал открытых данных Правительства Москвы: Пассажиропоток по станциям Московского метрополитена

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Скачиваем данные, определяем разделитель, пропускаем некоторые строки для корректной загрузки и загружаем данные в датафрейм.

# %%
df = pd.read_csv("C:\\Users\\Mariya\\Downloads\\Пассажиропоток_МосМетро_3.csv", sep = '|',
                 skiprows=[0, 1, 2, 3, 5, 6, 1380])

# %% [markdown]
# Получение первых 10 строк таблицы.

# %%
df.head(10)
# Out:
#        NameOfStation                       Line    Year    Quarter  \
# 0             Митино  Арбатско-Покровская линия  2021.0  I квартал
# 1      Волоколамская  Арбатско-Покровская линия  2021.0  I квартал
# 2           Строгино  Арбатско-Покровская линия  2021.0  I квартал
# 3         Крылатское  Арбатско-Покровская линия  2021.0  I квартал
# 4  Площадь Революции  Арбатско-Покровская линия  2021.0  I квартал
# 5         Бауманская  Арбатско-Покровская линия  2021.0  I квартал
# 6       Первомайская  Арбатско-Покровская линия  2021.0  I квартал
# 7        Беломорская       Замоскворецкая линия  2021.0  I квартал
# 8      Речной вокзал       Замоскворецкая линия  2021.0  I квартал
# 9     Водный стадион       Замоскворецкая линия  2021.0  I квартал
#
#    IncomingPassengers  OutgoingPassengers     global_id  NameOfStation_en  \
# 0           1913498.0           1829031.0  1.138976e+09               NaN
# 1           1236714.0           1222309.0  1.138976e+09               NaN
# ...

# %% [markdown]
# Общая информация о данных таблицы df

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1373 entries, 0 to 1372
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   NameOfStation          1373 non-null   str
#  1   Line                   1372 non-null   str
#  2   Year                   1372 non-null   float64
#  3   Quarter                1372 non-null   str
#  4   IncomingPassengers     1372 non-null   float64
#  5   OutgoingPassengers     1372 non-null   float64
#  6   global_id              1372 non-null   float64
#  7   NameOfStation_en       0 non-null      float64
#  8   Line_en                0 non-null      float64
#  9   Year_en                0 non-null      float64
#  10  Quarter_en             0 non-null      float64
#  11  IncomingPassengers_en  0 non-null      float64
#  12  OutgoingPassengers_en  0 non-null      float64
#  13  Unnamed: 13            0 non-null      float64
# dtypes: float64(11), str(3)
# ...

# %% [markdown]
# ##  Этап 2. Решение задачи

# %% [markdown]
# Определяем сколько всего было входов по всем станциям за всё время (сумма по столбцу IncomingPassengers)

# %%
pd.set_option('display.width', None)
result = df['IncomingPassengers'].sum()
print(f'{result:.0f}')
# Out:
# 2514195123

# %% [markdown]
# ## Задание 2
# ### Этап 1. Получение данных
#
# Сначала изучим данные, предоставленные для проекта.
#
# Набор данных содержит подробную информацию об общем количестве проходов пассажиров на станции метрополитена через турникеты по входу и об общем количестве выходов, осуществленных пассажирами со станций метрополитена.
# Источник данных: Портал открытых данных Правительства Москвы: Пассажиропоток по станциям Московского метрополитена

# %% [markdown]
# Скачиваем данные, определяем разделитель, конвертируем 0, NULL, None, не указано в NaN и загружаем данные в датафрейм.

# %%
df2 = pd.read_csv("C:\\Users\\Mariya\\Downloads\\Пассажиропоток_МосМетро_4.csv", sep = '|',
                 skiprows=[1], na_values={'IncomingPassengers' : [0, 'не указано']})
pd.set_option('display.width', None)

# %% [markdown]
# Получение первых 10 строк таблицы.

# %%
df2.head(10)
# Out:
#        NameOfStation                       Line  Year    Quarter  \
# 0             Митино  Арбатско-Покровская линия  2021  I квартал
# 1      Волоколамская  Арбатско-Покровская линия  2021  I квартал
# 2           Строгино  Арбатско-Покровская линия  2021  I квартал
# 3         Крылатское  Арбатско-Покровская линия  2021  I квартал
# 4  Площадь Революции  Арбатско-Покровская линия  2021  I квартал
# 5         Бауманская  Арбатско-Покровская линия  2021  I квартал
# 6       Первомайская  Арбатско-Покровская линия  2021  I квартал
# 7        Беломорская       Замоскворецкая линия  2021  I квартал
# 8      Речной вокзал       Замоскворецкая линия  2021  I квартал
# 9     Водный стадион       Замоскворецкая линия  2021  I квартал
#
#    IncomingPassengers  OutgoingPassengers   global_id  NameOfStation_en  \
# 0           1913498.0           1829031.0  1138975996               NaN
# 1           1236714.0           1222309.0  1138975997               NaN
# ...

# %% [markdown]
# Общая информация о данных таблицы df

# %%
df2.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1372 entries, 0 to 1371
# Data columns (total 14 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   NameOfStation          1372 non-null   str
#  1   Line                   1372 non-null   str
#  2   Year                   1372 non-null   int64
#  3   Quarter                1372 non-null   str
#  4   IncomingPassengers     1335 non-null   float64
#  5   OutgoingPassengers     1371 non-null   float64
#  6   global_id              1372 non-null   int64
#  7   NameOfStation_en       0 non-null      float64
#  8   Line_en                0 non-null      float64
#  9   Year_en                0 non-null      float64
#  10  Quarter_en             0 non-null      float64
#  11  IncomingPassengers_en  0 non-null      float64
#  12  OutgoingPassengers_en  0 non-null      float64
#  13  Unnamed: 13            0 non-null      float64
# dtypes: float64(9), int64(2), str(3)
# ...

# %% [markdown]
# ##  Этап 2. Решение задачи

# %% [markdown]
# Определяем количество записей, у которых пропущено значение в столбце 'IncomingPassengers'

# %%
mask = df2['IncomingPassengers'].isnull()
print(len(df2[mask]['IncomingPassengers']))
# Out:
# 37
